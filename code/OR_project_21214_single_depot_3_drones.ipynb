# %%
using CSV
using Distances
using Random

# %%
Random.seed!(4)
n = 20      # The number of patients
c_2 = 5     # unit distance cost
patients = [2:n+1;]
V = [1:n+1;]  # 1 denotes depot.    
q = [rand(12:15,n+1);]   # Requirment of each patient
arcs = []
for i in V
    for j in V 
        push!(arcs,(i,j))
    end
end
Q = 100    # Capacity
D = 10  # Max flying distance
q
# Out:
# 21-element Array{Int64,1}:
#  15
#  15
#  12
#  14
#  14
#  13
#  12
#  15
#  15
#  12
#  15
#  15
#  14
#  12
#  13
#  14
#  15
#  15
#  15
#  15
#  14

# %%
data = CSV.read("Patients21214_TableToExcel.csv")
# Out:
# 21×4 DataFrames.DataFrame
# │ Row │ OID   │ CID   │ POINT_X  │ POINT_Y │
# │     │ Int64 │ Int64 │ Float64  │ Float64 │
# ├─────┼───────┼───────┼──────────┼─────────┤
# │ 1   │ 0     │ 0     │ -76.5617 │ 39.3524 │
# │ 2   │ 1     │ 1     │ -76.5695 │ 39.3364 │
# │ 3   │ 2     │ 2     │ -76.5613 │ 39.3383 │
# │ 4   │ 3     │ 3     │ -76.5504 │ 39.3508 │
# │ 5   │ 4     │ 4     │ -76.5682 │ 39.362  │
# │ 6   │ 5     │ 5     │ -76.5583 │ 39.3494 │
# │ 7   │ 6     │ 6     │ -76.579  │ 39.3474 │
# │ 8   │ 7     │ 7     │ -76.5558 │ 39.3603 │
# │ 9   │ 8     │ 8     │ -76.563  │ 39.3652 │
# │ 10  │ 9     │ 9     │ -76.5656 │ 39.352  │
# │ 11  │ 10    │ 10    │ -76.5734 │ 39.3453 │
# │ 12  │ 11    │ 11    │ -76.5607 │ 39.3557 │
# │ 13  │ 12    │ 12    │ -76.5716 │ 39.3499 │
# │ 14  │ 13    │ 13    │ -76.5713 │ 39.3551 │
# │ 15  │ 14    │ 14    │ -76.5762 │ 39.3392 │
# │ 16  │ 15    │ 15    │ -76.5507 │ 39.3577 │
# │ 17  │ 16    │ 16    │ -76.5605 │ 39.3496 │
# │ 18  │ 17    │ 17    │ -76.5629 │ 39.3447 │
# │ 19  │ 18    │ 18    │ -76.5631 │ 39.3486 │
# │ 20  │ 19    │ 19    │ -76.5682 │ 39.3481 │
# │ 21  │ 20    │ 20    │ -76.5683 │ 39.3437 │

# %%
x_loc = data[:,3];
y_loc = data[:,4];
d = zeros(n+1,n+1)   # Distance matrix
for i = 1: length(V)
    for j = 1: length(V)
        d[i,j] = haversine((x_loc[i],y_loc[i]),(x_loc[j],y_loc[j]),6372.8) 
    end
end
d
# Out:
# 21×21 Array{Float64,2}:
#  0.0       1.90638   1.5708    0.988645  …  0.446169  0.740393  1.12463
#  1.90638   0.0       0.732939  2.29834      1.46164   1.31052   0.823554
#  1.5708    0.732939  0.0       1.68166      1.15375   1.24407   0.855072
#  0.988645  2.29834   1.68166   0.0          1.12801   1.56688   1.73702
#  1.20083   2.84838   2.69785   1.97172      1.55116   1.54      2.02834
#  0.442061  1.73457   1.25928   0.705256  …  0.422781  0.862436  1.06606
#  1.59118   1.47947   1.83039   2.49281      1.37013   0.929567  1.00538
#  1.01226   2.90987   2.49334   1.15373      1.45004   1.72712   2.13684
#  1.42326   3.25164   2.99273   1.93015      1.84647   1.95038   2.42982
#  0.33765   1.76791   1.56459   1.31296      0.431385  0.487566  0.94869
#  1.286     1.04709   1.29899   2.07754   …  0.95699   0.546763  0.469078
#  0.373232  2.27646   1.93561   1.04387      0.81887   1.06162   1.48362
#  0.899612  1.5108    1.5601    1.82905      0.73985   0.347045  0.736389
#  0.881433  2.09172   2.05932   1.86349      1.01121   0.822715  1.29287
#  1.925     0.658819  1.28203   2.56684      1.52742   1.20055   0.837735
#  1.11451   2.8708    2.34413   0.764737  …  1.47797   1.85004   2.17502
#  0.333776  1.65808   1.25489   0.881374     0.254724  0.686637  0.93799
#  0.868363  1.08077   0.72235   1.2791       0.434411  0.596419  0.47832
#  0.446169  1.46164   1.15375   1.12801      0.0       0.440729  0.700556
#  0.740393  1.31052   1.24407   1.56688      0.440729  0.0       0.488395
#  1.12463   0.823554  0.855072  1.73702   …  0.700556  0.488395  0.0

# %%
using JuMP, Gurobi 
v = 1:3  # # of drones
m = Model(Gurobi.Optimizer);
@variable(m,x[arcs,v],Bin) #arcs covered by vehicle k
@variable(m,u[1:n+1,v])
# Each patient will be visited exactly once
@constraint(m,single1[j in patients],sum(x[(i,j),k] for i in V for k in v)==1) 
@constraint(m,single2[i in patients],sum(x[(i,j),k] for j in V for k in v)==1) 
# Drone starts from depot
@constraint(m,depot1[k in v],sum(x[(1,j),k] for j in patients)==1)
# Drone ends at depot
@constraint(m,depot2[k in v],sum(x[(i,1),k] for i in patients)==1)
# Capacity constriant
@constraint(m,capacity[k in v],sum(q[i]*x[(i,j),k] for i in patients for j in V)<=Q)
# Balance constraint
@constraint(m,balance[h in patients,k in v],sum(x[(i,h),k] for i in V)-sum(x[(h,j),k] for j in V)==0) 
# Subtour Elimination MTZ
@constraint(m,subtour1[k in v], u[1,k]==1)
@constraint(m,subtour2[k in v,i in 2:n+1], u[i,k]>=2)   
@constraint(m,subtour3[k in v,i in 2:n+1], u[i,k]<=n)
@constraint(m,subtour4[k in v,i in 2:n+1, j in 2:n+1], (u[i,k]-u[j,k]+1)<=(n-1)*(1-x[(i,j),k]))
# Maximum flying distance for each drone
@constraint(m,maxdis[k in v], sum(d[i,j]*x[(i,j),k] for i in V for j in V)<=D)                                             
# Objective Function
@objective(m,Min,5*sum(d[i,j]*x[(i,j),k] for i in V for j in V for k in v))                                                              
optimize!(m)
@show objective_value(m);
# Out:
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Gurobi Optimizer version 9.0.1 build v9.0.1rc0 (win64)
# Optimize a model with 1435 rows, 1386 columns and 11163 nonzeros
# Model fingerprint: 0x429e113a
# Variable types: 63 continuous, 1323 integer (1323 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 2e+01]
#   Objective range  [9e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 183 rows and 66 columns
# Presolve time: 0.02s
# Presolved: 1252 rows, 1320 columns, 10734 nonzeros
# Variable types: 60 continuous, 1260 integer (1260 binary)
#
# Root relaxation: objective 6.029585e+01, 104 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   60.29585    0   32          -   60.29585      -     -    0s
#      0     0   60.41733    0   68          -   60.41733      -     -    0s
# H    0     0                     136.9944594   60.41733  55.9%     -    0s
#      0     0   61.45361    0   77  136.99446   61.45361  55.1%     -    0s
# H    0     0                      83.0700570   61.45361  26.0%     -    0s
#      0     0   62.51885    0   55   83.07006   62.51885  24.7%     -    0s
#      0     0   62.51885    0   55   83.07006   62.51885  24.7%     -    0s
# H    0     0                      76.5177457   62.51885  18.3%     -    0s
#      0     0   62.51885    0   42   76.51775   62.51885  18.3%     -    0s
#      0     0   62.51885    0   46   76.51775   62.51885  18.3%     -    0s
#      0     0   62.51885    0   46   76.51775   62.51885  18.3%     -    0s
#  322745 111705   69.66575   56   27   70.60467   68.47100  3.02%  13.9  175s
#  333591 112038     cutoff   81        70.60467   68.54061  2.92%  13.9  180s
#  343924 112023     cutoff   43        70.60467   68.61378  2.82%  14.0  185s
#  354705 112189     cutoff   51        70.60467   68.68403  2.72%  14.0  190s
#  364692 112143     cutoff   66        70.60467   68.75367  2.62%  14.0  195s
#  376676 111375   69.38764   43   32   70.60467   68.83194  2.51%  14.0  200s
#  386579 111036   70.15781   39   29   70.60467   68.89445  2.42%  14.0  205s
#  397684 110103   69.04130   60   14   70.60467   68.96398  2.32%  14.0  210s
#  408056 109337   70.44761   57   26   70.60467   69.02901  2.23%  14.0  215s
#  418636 108252   70.38422   66   33   70.60467   69.09224  2.14%  14.0  220s
#  429081 106383   69.69870   52   27   70.60467   69.15943  2.05%  14.0  225s
#  439083 104343     cutoff   87        70.60467   69.21176  1.97%  14.0  230s
#  449122 102261   69.52841   50   71   70.60467   69.27079  1.89%  14.0  235s
#  460384 99211     cutoff   65        70.60467   69.33756  1.79%  14.0  240s
#  471298 96640   70.23025   52   33   70.60467   69.39918  1.71%  14.0  245s
#  481873 93058     cutoff   57        70.60467   69.45653  1.63%  14.0  250s
#  492248 89770     cutoff   52        70.60467   69.51879  1.54%  14.0  255s
#  502152 86455     cutoff   56        70.60467   69.57363  1.46%  14.0  260s
#  511870 83006   70.60434   83   53   70.60467   69.63432  1.37%  13.9  265s
#  522124 78536     cutoff   90        70.60467   69.69478  1.29%  13.9  270s
#  533838 73514     cutoff   44        70.60467   69.76338  1.19%  13.9  275s
#  545178 68125   70.45985   65   31   70.60467   69.83542  1.09%  13.8  280s
#  555150 62871     cutoff   53        70.60467   69.90166  1.00%  13.8  285s
#  566638 56477   70.15482   47   41   70.60467   69.97779  0.89%  13.8  290s
#  577595 50046   70.35066   56   20   70.60467   70.05252  0.78%  13.7  295s
#  589416 41977     cutoff   53        70.60467   70.13598  0.66%  13.6  300s
#  600204 34287     cutoff   73        70.60467   70.21577  0.55%  13.6  305s
#  612990 24665     cutoff   51        70.60467   70.31383  0.41%  13.5  310s
#  624083 15228     cutoff   46        70.60467   70.41096  0.27%  13.4  315s
#  637552  2650     cutoff   86        70.60467   70.55431  0.07%  13.3  320s
#
# Cutting planes:
#   Gomory: 16
#   Implied bound: 3
#   Projected implied bound: 7
#   MIR: 35
#   Flow cover: 210
#   GUB cover: 4
#   Inf proof: 27
#   Zero half: 64
#   RLT: 113
#   Relax-and-lift: 16
#
# Explored 641473 nodes (8490015 simplex iterations) in 321.54 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 70.6047 71.5403 72.2237 ... 76.5177
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.060466758702e+01, best bound 7.060336720831e+01, gap 0.0018%
# objective_value(m) = 70.60466758701635

# %%
val = value.(x)
for k in v
    for i in V
        for j in V
            if val[(i,j),k]==1
                println(x[(i,j),k])
            end 
        end
    end
end
# Out:
# x[(1, 17),1]
# x[(10, 1),1]
# x[(13, 14),1]
# x[(14, 10),1]
# x[(17, 19),1]
# x[(19, 20),1]
# x[(20, 13),1]
# x[(1, 18),2]
# x[(2, 15),2]
# x[(3, 2),2]
# x[(7, 11),2]
# x[(11, 21),2]
# x[(15, 7),2]
# x[(18, 3),2]
# x[(21, 1),2]
# x[(1, 6),3]
# x[(4, 16),3]
# x[(5, 12),3]
# x[(6, 4),3]
# x[(8, 9),3]
# x[(9, 5),3]
# x[(12, 1),3]
# x[(16, 8),3]
